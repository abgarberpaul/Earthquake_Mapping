# %%
import requests
import json
from pprint import pprint

# %%
target_url = ("https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_month.geojson")

# %%
# Run a request to endpoint and convert result to json
data = requests.get(target_url).json()

# Print the json
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "bbox": [
#         -179.9927,
#         -63.1803,
#         -1.59,
#         179.9937,
#         73.5875,
#         644.9
#     ],
#     "features": [
#         {
#             "geometry": {
#                 "coordinates": [
#                     -98.1602,
#                     -36.4258,
#                     10
#                 ],
#                 "type": "Point"
#             },
#             "id": "us6000de34",
#             "properties": {
#                 "alert": null,
#                 "cdi": null,
#                 "code": "6000de34",
#                 "detail": "https://earthquake.usgs.gov/earthquakes/feed/v1.0/detail/us6000de34.geojson",
#                 "dmin": 13.268,
#                 "felt": null,
#                 "gap": 69,
#                 "ids": ",pt21034001,at00qnxtnq,us6000de34,",
#                 "mag": 6.9,
#                 "magType": "mww",
#                 "mmi": null,
#                 "net": "us",
#                 "nst": null,
# ...

# %%
# LOCATE latitude and longitude 
# [0] refers to the item in the first position.

place= data["features"][0]["properties"]["place"]
lat = data["features"][0]["geometry"]["coordinates"][1]
lng = data["features"][0]["geometry"]["coordinates"][0]
depth =  data["features"][0]["geometry"]["coordinates"][2]
mag = data["features"][0]["properties"]["mag"]

# Print the latitude and longitude
print('''
    Place: {place}
    Latitude: {lat}
    Longitude: {lng}
    Depth: {depth}
    Magnitude:{mag}
    ''')
#     ''').format(place, lat, lng, depth, mag)
# Out:
#     Place: {place}
#     Latitude: {lat}
#     Longitude: {lng}
#     Depth: {depth}
#     Magnitude:{mag}

# %%
meta = data["metadata"]
pprint(meta)
# Out:
# {'api': '1.10.3',
#  'count': 1711,
#  'generated': 1612331199000,
#  'status': 200,
#  'title': 'USGS Magnitude 2.5+ Earthquakes, Past Month',
#  'url': 'https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_month.geojson'}

# %%
# Extract latitude and longitude
lat = geo_data["results"][0]["geometry"]["location"]["lat"]
lng = geo_data["results"][0]["geometry"]["location"]["lng"]

# Print the latitude and longitude
print('''
    City: {0}
    Latitude: {1}
    Longitude: {2}
    ''').format(target_city, lat, lng))
# Out:
#   File "<ipython-input-9-7dde9879a737>", line 10
#     ''').format(target_city, lat, lng))
#
# ^
# SyntaxError: invalid syntax

# %%
time = data["features"][0]["properties"]["time"]

print(time)
# Out:
# 1612329821811

# %%
new Date (time)
# Out:
#   File "<ipython-input-14-99841af26095>", line 1
#     new Date (time)
#            ^
# SyntaxError: invalid syntax

# %%
toDate = Date.parse(time)
print(toDate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-ce09ce8f821d> in <module>
# ----> 1 toDate = Date.parse(time)
#       2 print(toDate)
#
# NameError: name 'Date' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2d702e403b39> in <module>
# ----> 1 Date.now()
#
# NameError: name 'Date' is not defined
